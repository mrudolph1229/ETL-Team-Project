# %%
from bs4 import BeautifulSoup
from splinter import Browser
import requests
import pymongo
import pandas as pd
import time
import keyboard
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()
from userpasswd import username, passwd

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
# Define database and collection
db = client.soccer_db

# %%
#players = db.players_info.find()
player_info_df1 = pd.DataFrame(list(db.players_info.find()))
player_info_df1.head()
# Out:
#                         _id  \
# 0  5c7de78a4537583a4cf57655
# 1  5c7de78a4537583a4cf57656
# 2  5c7de78a4537583a4cf57657
# 3  5c7de78a4537583a4cf57658
# 4  5c7de78a4537583a4cf57659
#
#                                       full_image_url            name  \
# 0  https://premierleague-static-files.s3.amazonaw...  Rolando Aarons
# 1  https://premierleague-static-files.s3.amazonaw...   Tammy Abraham
# 2  https://premierleague-static-files.s3.amazonaw...          Adrián
# 3  https://premierleague-static-files.s3.amazonaw...    Adrien Silva
# 4  https://premierleague-static-files.s3.amazonaw...     Benik Afobe
#
#                                          player_info
# 0  https://www.premierleague.com/players/10483/Ro...
# 1  https://www.premierleague.com/players/13286/Ta...
# 2  https://www.premierleague.com/players/4852/Adr...
# 3  https://www.premierleague.com/players/11357/Ad...
# 4  https://www.premierleague.com/players/4040/Ben...

# %%
player_info_df = player_info_df1[["name", "player_info", "full_image_url"]]
player_info_df.head()
# Out:
#              name                                        player_info  \
# 0  Rolando Aarons  https://www.premierleague.com/players/10483/Ro...
# 1   Tammy Abraham  https://www.premierleague.com/players/13286/Ta...
# 2          Adrián  https://www.premierleague.com/players/4852/Adr...
# 3    Adrien Silva  https://www.premierleague.com/players/11357/Ad...
# 4     Benik Afobe  https://www.premierleague.com/players/4040/Ben...
#
#                                       full_image_url
# 0  https://premierleague-static-files.s3.amazonaw...
# 1  https://premierleague-static-files.s3.amazonaw...
# 2  https://premierleague-static-files.s3.amazonaw...
# 3  https://premierleague-static-files.s3.amazonaw...
# 4  https://premierleague-static-files.s3.amazonaw...

# %%
con_string = f'{username}:{passwd}@127.0.0.1:3306/soccer_players'
conn_string = con_string
engine = create_engine(f'mysql://{conn_string}')
conn = engine.connect()

# %%
#player_data_df = pd.read_sql("select * from player_data where name like '%s''", names, engine)
player_data_df = pd.read_sql('select * from player_data', con=engine)
player_data_df.head()
# Out:
#    id               name     club  age  mkt_value     nationality
# 0   0     Alexis Sanchez  Arsenal   28       65.0           Chile
# 1   1         Mesut Ozil  Arsenal   28       50.0         Germany
# 2   2          Petr Cech  Arsenal   35        7.0  Czech Republic
# 3   3       Theo Walcott  Arsenal   28       20.0         England
# 4   4  Laurent Koscielny  Arsenal   31       22.0          France

# %%
names = "abcdef"
player_data_df["Select"] = player_data_df["name"].str.contains(names, case=False, regex=False)
player_data_df = player_data_df.loc[player_data_df["Select"] == True, :]
player_data_df.head()
# Out:
# Empty DataFrame
# Columns: [id, name, club, age, mkt_value, nationality, Select]
# Index: []

# %%
print(player_data_df.index)
if player_data_df.index.empty:
    print("Contains Data")
else:
    print("Does not contain Data")
# Out:
# Int64Index([], dtype='int64')
# Contains Data

# %%
# Merge the columns
comb_df = pd.merge(player_data_df, player_info_df, on="name", how="inner")
comb_df
#print(comb_df["player_info"])
#print(comb_df["full_image_url"])

# %%
#comb_ls_dict = comb_df.to_dict('records')
comb_dict = comb_df.to_dict('records')
#comb_dict = dict(comb_ls_dict)
comb_dict
